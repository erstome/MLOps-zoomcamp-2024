# %% [markdown]
# # Homework 05 - Monitoring
# Emanuel Tomé\
# June 2024

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd

# %% [markdown]
# ## Q1. Prepare the dataset

# %%
data = pd.read_parquet('../data/green_tripdata_2024-03.parquet')

# %%
data['date'] = data['lpep_pickup_datetime'].dt.date

# %%
# solution: 57457 rows, 20 columns

# %% [markdown]
# ## Q2. Metric

# %%
# solution: ColumnQuantileMetric(column_name="fare_amount", quantile=0.5)

# %% [markdown]
# ## Q3. Monitoring

# %%
# solution: 14.2

# %% [markdown]
# ## Q4. Dashboard

# %%
# solution: project_folder/dashboards
