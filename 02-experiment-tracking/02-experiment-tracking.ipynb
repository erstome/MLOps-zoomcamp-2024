# %% [markdown]
# # Homework 02 - Experiment Tracking
# Emanuel Tomé\
# May 2024

# %% [markdown]
# ## 1. Load packages

# %%
import mlflow
import os
from sklearn. ensemble import RandomForestRegressor

# %% [markdown]
# ## 2. Q1 - Install MLflow

# %%
print(mlflow.__version__)
# Out:
# 2.13.0

# %% [markdown]
# ## 3. Q2 - Download and preprocess the data

# %%
len(os.listdir('../output/'))
# Out:
# 4

# %% [markdown]
# ## Q3 - Train a model with autolog

# %%
# answer = 2

# %% [markdown]
# ## Q4 - Launch the tracking server locally

# %%
# answer = default-artifact-root

# %% [markdown]
# ## Q5 - Tune model hyperparameters

# %%
# answer = 5.335

# %% [markdown]
# ## Q6 - Promote the best model to the model registry

# %%
# answer = 5.567
