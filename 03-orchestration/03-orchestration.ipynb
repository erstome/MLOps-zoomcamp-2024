# %% [markdown]
# # Homework 03 - Orchestration
# Emanuel Tomé\
# June 2024

# %% [markdown]
# ## 1. Q1 - Run Mage

# %%
# Answer: v.0.9.71

# %% [markdown]
# ## 2. Q2 - Creating a project

# %%
# Answer: 55

# %% [markdown]
# ## 3. Q3 - Creating a pipeline

# %%
# Answer: 3403766

# %% [markdown]
# ## 4. Q4- Data preparation

# %%
# answer: 3316216

# %% [markdown]
# ## 5. Q5 - Train a model

# %%
# Answer:

# %% [markdown]
# ## 6. Q6 - MLFlow

# %%
# Answer:
